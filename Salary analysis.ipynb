# %%
# We use pd.read_csv for reading the file
import pandas as pd 
import csv
sal = pd.read_csv('Salaries.csv', index_col=None)
sal.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
sal.info() # .info is used for the information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
import numpy as np

# %%
sal['BasePay'].median() # we calculated median for basepay
# Out:
# 65007.45

# %%
sal['TotalPay'].mean() # calculated median for tosd
# Out:
# 567595.43

# %%
sal['OvertimePay'].min() # calculated min for overtimepay
# Out:
# -0.01

# %%
sal['TotalPay'].max() # calculated max for totalpay
# Out:
# 567595.43

# %%
sal['OtherPay'].max() # calculated max for otherpay
# Out:
# 400184.25

# %%
sal['BasePay'].min() # calculated min for basepay
# Out:
# -166.01

# %%
t = sal[sal['EmployeeName'] == 'DAVID SULLIVAN']  # finding info using using employee name
t.head()
# Out:
#           Id    EmployeeName                   JobTitle   BasePay  \
# 5          6  DAVID SULLIVAN  ASSISTANT DEPUTY CHIEF II  118602.0
# 10120  10121  DAVID SULLIVAN                PLANNER III   94758.0
#
#        OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 5           8601.0  189082.74       NaN  316285.74         316285.74  2011
# 10120          0.0    1716.92       NaN   96474.92          96474.92  2011
#
#        Notes         Agency  Status
# 5        NaN  San Francisco     NaN
# 10120    NaN  San Francisco     NaN

# %%
sal[sal['OvertimePay']== sal['OvertimePay'].min()] #finding info who has min overtimepay
# Out:
#           Id       EmployeeName                   JobTitle   BasePay  \
# 90714  90715  Claudia M Sanchez  Senior Eligibility Worker  75033.03
#
#        OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 90714        -0.01    1540.0  28864.64  76573.02         105437.66  2013
#
#        Notes         Agency  Status
# 90714    NaN  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits']== sal['TotalPayBenefits'].min()] #['EmployeeName']
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
# I want max totalpay where I give an input
st = sal[sal['JobTitle'] == 'CAPTAIN III (POLICE DEPARTMENT)'].head(10000)
t = st[st['TotalPayBenefits'] == st['TotalPayBenefits'].max()]
t
# Out:
#    Id  EmployeeName                         JobTitle    BasePay  OvertimePay  \
# 1   2  GARY JIMENEZ  CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 1  137811.38       NaN  538909.28         538909.28  2011    NaN
#
#           Agency  Status
# 1  San Francisco     NaN

# %%
sp = sal[sal['JobTitle'] == 'ASSISTANT DEPUTY CHIEF II'].head()
t = st[st['OvertimePay'] == st['OvertimePay']]
t.mean()
# Out:
# Id                     670.189189
# BasePay             170183.408649
# OvertimePay          15874.425405
# OtherPay             25726.059189
# Benefits                      NaN
# TotalPay            211783.893243
# TotalPayBenefits    211783.893243
# Year                  2011.000000
# Notes                         NaN
# Status                        NaN
# dtype: float64

# %%
sr = sal[sal['JobTitle'] == 'DEPUTY DIRECTOR OF INVESTMENTS'].tail(1000)
w = sr[sr['BasePay'] == sr['BasePay'].min()]
w
# Out:
#    Id   EmployeeName                        JobTitle    BasePay  OvertimePay  \
# 7   8  DAVID KUSHNER  DEPUTY DIRECTOR OF INVESTMENTS  256576.96          0.0
#
#    OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 7   51322.5       NaN  307899.46         307899.46  2011    NaN
#
#           Agency  Status
# 7  San Francisco     NaN

# %%
r = sal.groupby('Year').mean()
r
# Out:
#             Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.0  63595.956517  4531.065429  3617.081926           NaN
# 2012   54542.5  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91728.5  69630.030216  5281.641980  3819.969007  23829.076572
# 2014  129593.0  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits  Notes  Status
# Year
# 2011  71744.103871      71744.103871    NaN     NaN
# 2012  74113.262265     100553.229232    NaN     NaN
# 2013  77611.443142     101440.519714    NaN     NaN
# 2014  75463.918140     100250.918884    NaN     NaN

# %%
u = sal.groupby('JobTitle').max()
u.head(5000)
# Out:
#                                                     Id           EmployeeName  \
# JobTitle
# ACCOUNT CLERK                                    35638            ZAIRE EARBY
# ACCOUNTANT                                       35286          ROSALINDA TAN
# ACCOUNTANT INTERN                                34267            YUMING CHEN
# ACPO,JuvP, Juv Prob (SFERS)                     135284  Palminder K Hernandez
# ACUPUNCTURIST                                    18379                 WEN XU
# ...                                                ...                    ...
# X-RAY LABORATORY AIDE                            33182            STANLEY LEE
# X-Ray Laboratory Aide                           143632             Zhe J Chen
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS   23392          MARIO YEDIDIA
# Youth Comm Advisor                              138459           Phimy Truong
# ZOO CURATOR                                      18779            MYRON SULAK
#
# ...

# %%
u = st.groupby('EmployeeName').max() # remember groupby is important for sorting and forming groupbys
u
# Out:
#                       Id                         JobTitle    BasePay  \
# EmployeeName
# ALBERT PARDINI         3  CAPTAIN III (POLICE DEPARTMENT)  212739.13
# ANN MANNIX           320  CAPTAIN III (POLICE DEPARTMENT)  188314.50
# ANNA BROWN            62  CAPTAIN III (POLICE DEPARTMENT)  102571.24
# ANTHONY FOTINOS     4144  CAPTAIN III (POLICE DEPARTMENT)   42738.00
# ANTONIO PARRA        254  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# CHARLIE ORKES        397  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# CROCE CASCIATO       212  CAPTAIN III (POLICE DEPARTMENT)  188341.62
# CURTIS LUM           526  CAPTAIN III (POLICE DEPARTMENT)  184700.97
# DANIEL MAHONEY       249  CAPTAIN III (POLICE DEPARTMENT)  196061.30
# DAVID LAZAR          297  CAPTAIN III (POLICE DEPARTMENT)  195975.32
# DENIS OLEARY         275  CAPTAIN III (POLICE DEPARTMENT)  188341.60
# DOMINIC CELAYA       368  CAPTAIN III (POLICE DEPARTMENT)  188341.64
# ...

# %%
type(sal['Id'])
# Out:
# pandas.core.series.Series

# %%
type(u)
# Out:
# pandas.core.frame.DataFrame

# %%
e = sal['OvertimePay'].nunique()
e
# Out:
# 65998

# %%
# we use count values for the order
import pandas as pd
sal = pd.read_csv('Salaries.csv', index_col=None)
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
f = sal['JobTitle'].value_counts().head()
f
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
import matplotlib as plot
f.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
f.plot()
# Out:
# <AxesSubplot:>

# %%
tx = sal.groupby('Year').mean()['OvertimePay']
tx.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
r = sal.groupby('JobTitle').mean()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

data = pd.read_csv("Salaries.csv").head(50)
X1 = data[['BasePay']]
Y1 = data[['TotalPayBenefits']]
X_train, X_test, y_train, y_test = train_test_split(X1,Y1,test_size = 0.3, random_state = 0)
regre = LinearRegression()
regre.fit(X_train,y_train)
y_predi = regre.predict(X_test)
print(y_test,y_predi)
print('Intercept', regre.intercept_)
print('Coefficient:\n', regre.coef_)
# Out:
#     TotalPayBenefits
# 28         264074.60
# 11         297608.92
# 10         299494.17
# 41         250408.49
# 2          335279.91
# 27         265463.46
# 38         251935.01
# 31         259927.11
# 22         273702.71
# 4          326373.19
# 33         258588.39
# 35         257540.09
# 26         265784.56
# 34         258364.22
# 18         276434.22 [[275774.72712049]
#  [311464.23594108]
#  [290473.52229943]
#  [296269.20652209]
#  [286565.25190687]
#  [296269.21533455]
#  [304308.45809424]
#  [277468.91666728]
#  [302470.04156259]
#  [303823.91799359]
#  [310331.96873914]
#  [310972.67671304]
#  [313147.68089143]
#  [294266.87816467]
#  [296269.20652209]]
# Intercept [333434.14869554]
# Coefficient:
#  [[-0.22031159]]

# %%
import matplotlib.pyplot as plot

# %%
data = sal.head(10)
data
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
# %matplotlib inline
plot.plot(data.BasePay,data.TotalPayBenefits)
plot.xlabel('Basepay')
plot.ylabel('TotalPayBenefits')
plot.rcParams['figure.figsize'] = [40,40]

# %%
import matplotlib as plot
data.plot(kind = 'line')
plot.rcParams['figure.figsize'] = [20,20]
